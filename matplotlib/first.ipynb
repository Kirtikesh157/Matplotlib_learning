# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8,10]

plt.plot(x, y)  
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Basic Line Graph")
plt.show()

# %%
plt.plot(x, y)

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(x, y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.scatter(x, y)

# %%
import numpy as np
data = np.random.randn(1000)
plt.hist(data, bins=30, color='orange')
# Out:
# (array([ 1.,  0.,  3.,  2.,  6.,  8., 17., 29., 49., 53., 51., 63., 75.,
#         91., 89., 90., 84., 63., 67., 49., 42., 25., 18.,  8.,  8.,  4.,
#          2.,  0.,  2.,  1.]),
#  array([-3.38193641, -3.14784787, -2.91375933, -2.67967078, -2.44558224,
#         -2.21149369, -1.97740515, -1.7433166 , -1.50922806, -1.27513952,
#         -1.04105097, -0.80696243, -0.57287388, -0.33878534, -0.10469679,
#          0.12939175,  0.36348029,  0.59756884,  0.83165738,  1.06574593,
#          1.29983447,  1.53392302,  1.76801156,  2.0021001 ,  2.23618865,
#          2.47027719,  2.70436574,  2.93845428,  3.17254283,  3.40663137,
#          3.64071991]),
#  <BarContainer object of 30 artists>)

# %%
sizes = [30, 20, 25, 25]
labels = ["A", "B", "C", "D"]
plt.pie(sizes, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22d802d54e0>,
#   <matplotlib.patches.Wedge at 0x22d802d5420>,
#   <matplotlib.patches.Wedge at 0x22d802d62f0>,
#   <matplotlib.patches.Wedge at 0x22d802d6aa0>],
#  [Text(0.6465637011386807, 0.8899187493079641, 'A'),
#   Text(-0.8899187390319623, 0.6465637152823859, 'B'),
#   Text(-0.7778173279449521, -0.7778175906654303, 'C'),
#   Text(0.7778177173879477, -0.7778172012223713, 'D')],
#  [Text(0.3526711097120076, 0.48541022689525304, '30.0%'),
#   Text(-0.4854102212901612, 0.3526711174267559, '20.0%'),
#   Text(-0.4242639970608829, -0.42426414036296195, '25.0%'),
#   Text(0.4242642094843351, -0.42426392793947526, '25.0%')])

# %%
plt.title("Graph Title")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
plt.plot(x, y, color="red", linestyle="--", marker="o")

# %%
plt.grid(True)

# %%
plt.plot(x, y, label="Line 1")
plt.legend()
